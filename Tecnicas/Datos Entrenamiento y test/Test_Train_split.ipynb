# %% [markdown]
# <a href="https://colab.research.google.com/github/AntFri/SAA/blob/main/Tecnicas/Datos%20Entrenamiento%20y%20test/Test_Train_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMporte de cada libreria necesarria.
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab_CSV_data/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
X = df[['age']]
y = df[['bought_insurance']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
X_train
# Out:
#     age
# 23   45
# 3    52
# 13   29
# 14   49
# 0    22
# 21   26
# 17   58
# 4    46
# 5    56
# 9    61
# 26   23
# 15   55
# 18   19
# 22   40
# 16   25
# 25   54
# 24   50
# 8    62
# 19   18
# 12   27
# 20   21

# %%
X_test
# Out:
#     age
# 6    55
# 11   28
# 7    60
# 1    25
# 2    47
# 10   18

# %%
y_train
# Out:
#     bought_insurance
# 23                 1
# 3                  0
# 13                 0
# 14                 1
# 0                  0
# 21                 0
# 17                 1
# 4                  1
# 5                  1
# 9                  1
# 26                 0
# 15                 1
# 18                 0
# 22                 1
# 16                 1
# 25                 1
# 24                 1
# 8                  1
# 19                 0
# 12                 0
# 20                 0

# %%
y_test
# Out:
#     bought_insurance
# 6                  0
# 11                 0
# 7                  1
# 1                  0
# 2                  1
# 10                 0

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([1, 0, 1, 0, 1, 0])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.04939844, 0.95060156],
#        [0.77308222, 0.22691778],
#        [0.02338949, 0.97661051],
#        [0.84429944, 0.15570056],
#        [0.15215778, 0.84784222],
#        [0.94131244, 0.05868756]])

# %%
model.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# 0.8333333333333334
