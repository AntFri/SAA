# %% [markdown]
# <a href="https://colab.research.google.com/github/AntFri/SAA/blob/main/Aprendizaje%20Supervisado/Regresi%C3%B3n/regresion%20lineal%20y%20polinimi/Liniear_regresion.ipynb/Liniear_regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importe de las librerias necesarias
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
data = { 'Area': [2600,3000,3200,3600,4000] ,
        'price':[550000,565000,610000,680000,725000]
}

df = pd.DataFrame(data)

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.xlabel('price')
plt.scatter(df.Area, df.price, color='red', marker='+')

# %%
new_df = df.drop('price', axis='columns')
price = df.price
price
reg= linear_model.LinearRegression()
reg.fit(new_df,price)

reg.predict([[120]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([196910.95890411])

# %% [markdown]
# ## Pratica RLS sueldo Medio:
# IMPORTANTE, tienes que añadir la csv con los datos.

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sueldo.csv')

new_df2 = df2.drop('sueldomedio', axis='columns')
sueldo = df2['sueldomedio']

reg= linear_model.LinearRegression()
reg.fit(new_df2,sueldo)
# Out:
# LinearRegression()

# %%
i = 2017
while i < 2025:
  pred = reg.predict([[i]])
  print(i, pred)
  i += 1


# %matplotlib inline
plt.xlabel('anyo')
plt.xlabel('sueldo medio')
plt.scatter(df2.anyo, df2.sueldomedio, color='red', marker='+')
# Out:
# 2017 [38803.29886875]
# 2018 [39631.76394397]
# 2019 [40460.22901919]
# 2020 [41288.69409442]
# 2021 [42117.15916964]
# 2022 [42945.62424486]
# 2023 [43774.08932009]
# 2024 [44602.55439531]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
