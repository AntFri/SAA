# %% [markdown]
# <a href="https://colab.research.google.com/github/AntFri/SAA/blob/main/Aprendizaje%20Supervisado/Clasificaci%C3%B3n/Regresion%20Logistica/SAA_Prac_RLogis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMporte de cada libreria necesarria.
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df['age'], df['bought_insurance'], color='purple', marker='x')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df[['bought_insurance']], train_size=0.8)

# %%
X_train
# Out:
#     age
# 19   18
# 17   58
# 1    25
# 25   54
# 16   25
# 7    60
# 4    46
# 11   28
# 18   19
# 26   23
# 20   21
# 23   45
# 2    47
# 5    56
# 10   18
# 3    52
# 24   50
# 14   49
# 12   27
# 22   40
# 0    22

# %%
X_test
# Out:
#     age
# 17   58
# 25   54
# 12   27
# 3    52
# 24   50
# 0    22

# %%
y_train
# Out:
#     bought_insurance
# 13                 0
# 2                  1
# 4                  1
# 10                 0
# 7                  1
# 11                 0
# 14                 1
# 8                  1
# 9                  1
# 23                 1
# 5                  1
# 18                 0
# 16                 1
# 6                  0
# 15                 1
# 22                 1
# 1                  0
# 26                 0
# 21                 0
# 19                 0
# 20                 0

# %%
y_test
# Out:
#     bought_insurance
# 17                 1
# 25                 1
# 12                 0
# 3                  0
# 24                 1
# 0                  0

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([1, 1, 1, 0, 0, 1])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.04383329, 0.95616671],
#        [0.01480069, 0.98519931],
#        [0.01731365, 0.98268635],
#        [0.82337228, 0.17662772],
#        [0.74292674, 0.25707326],
#        [0.04383329, 0.95616671]])

# %%
model.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# 0.8333333333333334

# %%
model.coef_
# Out:
# array([[0.15937596]])

# %%
model.intercept_
# Out:
# array([-5.68313928])
